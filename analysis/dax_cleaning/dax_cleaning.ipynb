# %%
import pandas as pd

# %%
df  = pd.read_csv('../../data/input/XETR_DLY_DAX, 1W .csv')

# %% [markdown]
# ## DF overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time               1692 non-null   int64
#  1   open               1692 non-null   float64
#  2   high               1692 non-null   float64
#  3   low                1692 non-null   float64
#  4   close              1692 non-null   float64
#  5   DE05Y, TVC: Open   1670 non-null   float64
#  6   DE05Y, TVC: High   1670 non-null   float64
#  7   DE05Y, TVC: Low    1670 non-null   float64
#  8   DE05Y, TVC: Close  1670 non-null   float64
#  9   DE30Y, TVC: Open   1350 non-null   float64
#  10  DE30Y, TVC: High   1350 non-null   float64
#  11  DE30Y, TVC: Low    1350 non-null   float64
#  12  DE30Y, TVC: Close  1350 non-null   float64
#  13  DE10Y, TVC: Open   1627 non-null   float64
#  14  DE10Y, TVC: High   1627 non-null   float64
# ...

# %% [markdown]
# ## General DataFrame Cleaning

# %%
df.tail(2)
# Out:
#             time      open      high       low     close  DE05Y, TVC: Open  \
# 1690  1606723200  13270.51  13445.11  13223.93  13298.96           -0.7692
# 1691  1607328000  13255.78  13454.13  13009.48  13114.30           -0.7523
#
#       DE05Y, TVC: High  DE05Y, TVC: Low  DE05Y, TVC: Close  DE30Y, TVC: Open  \
# 1690           -0.7110          -0.7779            -0.7519           -0.1825
# 1691           -0.7523          -0.8182            -0.8104           -0.1212
#
#       ...  DE10Y, TVC: Open  DE10Y, TVC: High  DE10Y, TVC: Low  \
# 1690  ...           -0.5878           -0.5118          -0.5909
# 1691  ...           -0.5447           -0.5447          -0.6410
#
#       DE10Y, TVC: Close  Volume  Volume MA       SMA1          SMA2  \
# 1690            -0.5449     NaN        NaN  12818.012  12235.343386
# 1691            -0.6358     NaN        NaN  12860.538  12230.887186
#
#               SMA3          SMA4
# 1690  12189.126593  12274.426196
# 1691  12211.394993  12281.662846
#
# ...

# %%
df['date'] = pd.to_datetime(df['time'])

# %%
df.tail(2)
# Out:
#             time      open      high       low     close  DE05Y, TVC: Open  \
# 1690  1606723200  13270.51  13445.11  13223.93  13298.96           -0.7692
# 1691  1607328000  13255.78  13454.13  13009.48  13114.30           -0.7523
#
#       DE05Y, TVC: High  DE05Y, TVC: Low  DE05Y, TVC: Close  DE30Y, TVC: Open  \
# 1690           -0.7110          -0.7779            -0.7519           -0.1825
# 1691           -0.7523          -0.8182            -0.8104           -0.1212
#
#       ...  DE10Y, TVC: High  DE10Y, TVC: Low  DE10Y, TVC: Close  Volume  \
# 1690  ...           -0.5118          -0.5909            -0.5449     NaN
# 1691  ...           -0.5447          -0.6410            -0.6358     NaN
#
#       Volume MA       SMA1          SMA2          SMA3          SMA4  \
# 1690        NaN  12818.012  12235.343386  12189.126593  12274.426196
# 1691        NaN  12860.538  12230.887186  12211.394993  12281.662846
#
#                               date
# 1690 1970-01-01 00:00:01.606723200
# ...

# %%
df.head(2)
# Out:
#         time     open     high      low    close  DE05Y, TVC: Open  \
# 0  584607600  1193.02  1197.03  1168.24  1191.13             5.929
# 1  585212400  1194.87  1195.02  1152.50  1153.77             6.050
#
#    DE05Y, TVC: High  DE05Y, TVC: Low  DE05Y, TVC: Close  DE30Y, TVC: Open  \
# 0             5.975            5.896              5.975               NaN
# 1             6.050            5.987              6.000               NaN
#
#    ...  DE10Y, TVC: High  DE10Y, TVC: Low  DE10Y, TVC: Close  Volume  \
# 0  ...             6.748            6.684              6.748     NaN
# 1  ...             6.820            6.749              6.749     NaN
#
#    Volume MA        SMA1         SMA2         SMA3         SMA4  \
# 0        NaN  1111.86999  1166.979595  1270.505798  1196.651399
# 1        NaN  1125.46299  1158.864995  1267.352498  1198.419749
#
#                            date
# 0 1970-01-01 00:00:00.584607600
# 1 1970-01-01 00:00:00.585212400
#
# [2 rows x 24 columns]

# %%
df.drop(columns=['time'], inplace=True)

# %% [markdown]
# ## DF Slicing

# %%
close = df[['date',
            'close',
           'DE05Y, TVC: Close',
           'DE10Y, TVC: Close',
           'DE30Y, TVC: Close',
           'Volume']]

# %%
open_ = df[['date',
            'close',
           'DE05Y, TVC: Open',
           'DE10Y, TVC: Open',
           'DE30Y, TVC: Open',
           'Volume']]

# %%
high = df[['date',
            'close',
           'DE05Y, TVC: High',
           'DE10Y, TVC: High',
           'DE30Y, TVC: High',
           'Volume']]

# %%
low = df[['date',
            'close',
           'DE05Y, TVC: Low',
           'DE10Y, TVC: Low',
           'DE30Y, TVC: Low',
           'Volume']]

# %% [markdown]
# ### DF's to CSV's

# %%
close.to_csv('../../data/processed/dax_close')
open_.to_csv('../../data/processed/dax_open')
high.to_csv('../../data/processed/dax_high')
low.to_csv('../../data/processed/dax_low')
